# %%
import os
import sys
import re
import csv
import time
import random
import pickle
import argparse
import ahocorasick
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import OrderedDict

from nltk.corpus import stopwords, words, names
stops = stopwords.words("english")

# %%
def read_csv_to_list(filename):
	with open(filename) as f:  # relevant english words
		reader = csv.reader(f)
		csv_list = list(reader)
	csv_list = [c[0] for c in csv_list]
	return(csv_list)

def init_automaton(string_list):
	"""Make Aho-Corasick automaton from a list of strings"""
	A = ahocorasick.Automaton()
	for idx, s in enumerate(string_list):
		A.add_word(s, (idx, s))
	return A

def check_strings(A, search_list, string_to_search):
	"""Use Aho Corasick algorithm to produce boolean list indicating
	prescence of strings within a longer string"""
	index_list = []
	for item in A.iter(string_to_search):
		index_list.append(item[1][0])

	output_list = np.array([0] * len(search_list))
	output_list[index_list] = 1
	return output_list.tolist()

def build_url_feature_vector(A_company, search_list, string_to_search):
	"""Presence of search_list words in string, along with length of string"""
	feature_vector = check_strings(A_company, search_list, string_to_search)
	feature_vector.append(len(string_to_search))
	return feature_vector

# %%
# Load list of keywords
words_list = read_csv_to_list('data/word_feature_list.csv')
words_list = [w for w in words_list if w not in stops if len(w) > 1]
url_endings_list = read_csv_to_list('data/domains_endings.csv')
words_list = words_list + url_endings_list
del url_endings_list

A = init_automaton(words_list)
A.make_automaton()

# %%
## Test URL list
links_df = pd.read_csv('data/links_dataframe.csv')
url_list = links_df['url'].tolist()
url_list = [l.replace("http://", "").replace("https://", "") for l in url_list if type(l) is str if l[-4:] not in [".png", ".jpg", ".pdf", ".txt"]]
url_list = url_list[:200]

# %%
t0 = time.time()
next_state_list = [build_url_feature_vector(A, words_list, l) for l in url_list]
print(time.time()-t0)
# Out:
# 0.10703611373901367

# %%
url_df = pd.DataFrame.from_dict({"url":url_list})
url_df.apply(build_url_feature_vector, args=())
# Out:
#                                                    url
# 0      www.gjassociates.co.uk/service/36/Restructuring
# 1    www.sterling-accountants.com/our-services/sole...
# 2                       www.farrarsmith.co.uk/services
# 3    www.facebook.com/pages/Account-Ants-Darlington...
# 4      www.chesapeake.co.uk/services/personal-services
# 5    www.sheffieldlawsociety.co.uk/apply-for-member...
# 6                    www.sableinternational.com/wealth
# 7                    www.tribeuk.co.uk/work/microlise/
# 8               marcusbaum.co.uk/services/matrimonial/
# 9    www.cpaglobal.com/patent-portfolio-analysis-di...
# 10                               www.vineybecks.co.uk/
# 11                    www.grineaux.co.uk/key-services/
# 12                    www.act.london/impact-of-brexit/
# 13   plus.google.com/105913526117284566181/posts?hl=en
# 14   www.gregsons.co.uk/our-services/company-commer...
# 15               www.irisopenspace.co.uk/Account/LogOn
# 16   www.chorusaccounting.co.uk/our-services/person...
# 17     www.swissmanda.com/your-favorite-opportunities/
# 18                   pglegal.co.uk/corporate-solutions
# 19                 www.emmlegal.com/fraud-prosecution/
# 20   www.akhter.co.uk/index.php/download_file/view/...
# 21         www.cpaglobal.com/renew-patent-renewals-law
# 22   www.mcmorlandaccountants.co.uk/s/cc_images/cac...
# 23          www.mclegal.co.uk/beer-festival-trademark/
# 24   www.gannons.co.uk/company/acquisitions-disposa...
# 25                            www.gemfinanceltd.co.uk/
# 26                              asvsh.co.uk/pensions4/
# 27       www.reliant.com/en/about/media/reliant-tv.jsp
# 28   www.ouzmanip.com/2015/09/04/can-a-biscuit-be-a...
# 29                      www.facebook.com/SigilPickups/
# ..                                                 ...
# 170  www.aarp.org/entertainment/books/bookstore/?in...
# 171  www.jensonsolutions.com/services/change-manage...
# 172                              www.jamesmagee.co.uk/
# 173  news.google.co.uk/news/search?aq=f&pz=1&cf=all...
# 174          www.universalaw.co.uk/personal-injury.php
# 175                www.accounttech.co.uk/our-services/
# 176      www.rbwconsulting.com/job-2976-scra--cra.html
# 177                         ghtltd.com/sustainability/
# 178  www.armstrong-law.co.uk/personal-injury/catast...
# 179        www.sunmoonfood.com/category/press-release/
# 180                             www.akc.org/trick-dog/
# 181                           www.act.london/about-us/
# 182  www.menzieslaw.co.uk/testimonials/direct-wines...
# 183  www.sableinternational.com/immigration/uk-resi...
# 184                        www.warcuplawfirm.co.uk/faq
# 185  twitter.com/intent/retweet?tweet_id=8719960383...
# 186                          www.agtax.co.uk/services/
# 187                           twitter.com/NZTaxRefunds
# 188             www.mjhaccountants.co.uk/cookie-policy
# 189  www.myerssolicitors.co.uk/about-us/receive-a-c...
# 190  www.meer-co.com/case-studies-page/advisory-fue...
# 191  pinterest.com/pin/create/button/?url=http%3A%2...
# 192  www.cloudbasedaccounting.co.uk/xero-sage-cloud...
# 193   www.clarkeslaw.co.uk/children-&-social-services/
# 194  www.facebook.com/pages/Peter-Millican-Law/4912...
# 195           www.willwriting.co.uk/services/glossary/
# 196  www.fountainsolicitors.com/our-services/employ...
# 197     www.roedl.com/locations/europe/luxembourg.html
# 198  maps.google.com/maps?f=q&source=s_q&hl=en&geoc...
# 199  www.sableinternational.com/immigration/uk-resi...
#
# [200 rows x 1 columns]
